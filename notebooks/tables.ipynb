# %%
from __future__ import print_function
import pandas as pd
import os
import os.path as op

# %%
sagtbl = pd.read_csv("../data/hmp_tbls/sag_completeness.txt", sep="\t")
mgtbl = pd.read_csv("../data/hmp_tbls/multi_mg_qc.csv", sep="\t")
covtbl = pd.read_csv("../data/hmp_tbls/coverage_info.txt", sep="\t")

# %%
sagtbl
# Out:
#    Unnamed: 0  # genomes  # marker sets  # markers  0     1   2  3  4  5+  \
# 0           0        134            336       1173  7  1163   3  0  0   0
# 1           0        293            267        475  1   473   1  0  0   0
# 2           0        434            186        278  0   228  50  0  0   0
# 3           0         92            270        487  3   483   1  0  0   0
# 4           0       1487            161        256  3   216  37  0  0   0
#
#                       Bin Id  Completeness  Contamination  \
# 0        Ecoli4147faa.masked         99.35           0.12
# 1     EfaecalisTX1322.masked         99.63           0.19
# 2     OlaneusYIT12061.masked        100.00          20.97
# 3  PstercoreaDSM18206.masked         98.89           0.37
# 4     Swadsworthensis.masked         98.14          16.15
#
#                     Marker lineage  Strain heterogeneity  calculated_length  \
# 0  f__Enterobacteriaceae (UID5124)                   0.0            5290619
# 1      o__Lactobacillales (UID544)                   0.0            2940481
# 2            k__Bacteria (UID2569)                 100.0            4394574
# 3       o__Bacteroidales (UID2716)                   0.0            3127382
# 4      p__Proteobacteria (UID3887)                  97.3            2941130
#
#    total_bp
# 0   5256230
# 1   2929602
# 2   4394574
# 3   3092669
# 4   2886425

# %%
sagtbl['sag'] = [i.split(".")[0] for i in sagtbl['Bin Id']]

# %%
sagtbl.rename(columns={'Completeness':'sag_completeness', 
                           'total_bp':'sag_total_bp', 
                           'calculated_length':'sag_calculated_length'}, 
                           inplace=True)
sagshort = sagtbl[['sag', 'sag_completeness', 'sag_total_bp', 'sag_calculated_length']]

# %%
sagshort
# Out:
#                   sag  sag_completeness  sag_total_bp  sag_calculated_length
# 0        Ecoli4147faa             99.35       5256230                5290619
# 1     EfaecalisTX1322             99.63       2929602                2940481
# 2     OlaneusYIT12061            100.00       4394574                4394574
# 3  PstercoreaDSM18206             98.89       3092669                3127382
# 4     Swadsworthensis             98.14       2886425                2941130

# %%
mgtbl
# Out:
#    Unnamed: 0                                               mg_f  \
# 0           0  /mnt/stepanauskas_nfs/julia/testfragrecruitmen...
# 1           1  /mnt/stepanauskas_nfs/julia/testfragrecruitmen...
# 2           2  /mnt/stepanauskas_nfs/julia/testfragrecruitmen...
# 3           3  /mnt/stepanauskas_nfs/julia/testfragrecruitmen...
# 4           4  /mnt/stepanauskas_nfs/julia/testfragrecruitmen...
# 5           5  /mnt/stepanauskas_nfs/julia/testfragrecruitmen...
#
#                                                 mg_r wgs_technology   join  \
# 0  /mnt/stepanauskas_nfs/julia/testfragrecruitmen...       illumina   True
# 1  /mnt/stepanauskas_nfs/julia/testfragrecruitmen...       illumina   True
# 2  /mnt/stepanauskas_nfs/julia/testfragrecruitmen...       illumina   True
# 3                                               None           pyro  False
# 4                                               None           pyro  False
# 5                                               None           pyro  False
#
#         name  read_count                                         to_recruit
# 0  SRS019030     5325310  hmp_results/mgs/SRS019030.extendedFrags.minlen...
# 1  SRS022524        2518  hmp_results/mgs/SRS022524.extendedFrags.minlen...
# 2  SRS078197       27452  hmp_results/mgs/SRS078197.extendedFrags.minlen...
# 3  SRR063559      772443      hmp_results/mgs/SRR063559.minlen_150.fastq.gz
# 4  SRR063903     1323126      hmp_results/mgs/SRR063903.minlen_150.fastq.gz
# 5  SRR061736     1182987      hmp_results/mgs/SRR061736.minlen_150.fastq.gz

# %%
mgtbl.rename(columns={'name':'metagenome', 
                          'wgs_technology':'mg_wgs_technology', 
                          'read_count':'mg_read_count'}, 
                          inplace=True)
mgshort = mgtbl[['metagenome', 'mg_wgs_technology', 'mg_read_count']]

# %%
mgshort
# Out:
#   metagenome mg_wgs_technology  mg_read_count
# 0  SRS019030          illumina        5325310
# 1  SRS022524          illumina           2518
# 2  SRS078197          illumina          27452
# 3  SRR063559              pyro         772443
# 4  SRR063903              pyro        1323126
# 5  SRR061736              pyro        1182987

# %%
covtbl['sag'] = [i.split(".")[0] for i in covtbl['sag']]

# %%
summary = covtbl.merge(mgshort, how='outer', on='metagenome')

# %%
summary = summary.merge(sagshort, how='outer', on='sag')

# %%
summary
wgs_factors = {'illumina':0.8376, 'pyro':1}

# %%
summary['prop_mg_recruited'] = (summary.total_reads_recruited)*100/summary.sag_completeness/summary.mg_read_count
summary['prop_mg_adjusted'] = summary['prop_mg_recruited']*summary['mg_wgs_technology'].map(wgs_factors)

# %%
summary
# Out:
#     Unnamed: 0                 sag metagenome  \
# 0            0        Ecoli4147faa  SRS019030
# 1            0        Ecoli4147faa  SRS022524
# 2            0        Ecoli4147faa  SRS078197
# 3            0        Ecoli4147faa  SRR063559
# 4            0        Ecoli4147faa  SRR063903
# 5            0        Ecoli4147faa  SRR061736
# 6            0     EfaecalisTX1322  SRS019030
# 7            0     EfaecalisTX1322  SRS022524
# 8            0     EfaecalisTX1322  SRS078197
# 9            0     EfaecalisTX1322  SRR063559
# 10           0     EfaecalisTX1322  SRR063903
# 11           0     EfaecalisTX1322  SRR061736
# 12           0     OlaneusYIT12061  SRS019030
# 13           0     OlaneusYIT12061  SRS022524
# 14           0     OlaneusYIT12061  SRS078197
# 15           0     OlaneusYIT12061  SRR063559
# 16           0     OlaneusYIT12061  SRR063903
# 17           0     OlaneusYIT12061  SRR061736
# 18           0  PstercoreaDSM18206  SRS019030
# 19           0  PstercoreaDSM18206  SRS022524
# 20           0  PstercoreaDSM18206  SRS078197
# 21           0  PstercoreaDSM18206  SRR063559
# 22           0  PstercoreaDSM18206  SRR063903
# 23           0  PstercoreaDSM18206  SRR061736
# 24           0     Swadsworthensis  SRS019030
# 25           0     Swadsworthensis  SRS022524
# 26           0     Swadsworthensis  SRS078197
# 27           0     Swadsworthensis  SRR063559
# 28           0     Swadsworthensis  SRR063903
# 29           0     Swadsworthensis  SRR061736
#
#     Percent_scaffolds_with_any_coverage  Percent_of_reference_bases_covered  \
# 0                                   100                            7.366905
# 1                                   NaN                            0.000000
# 2                                   NaN                            0.000000
# 3                                   100                            3.687101
# 4                                   100                            0.631277
# 5                                   NaN                            0.000000
# 6                                   100                            2.404554
# 7                                   NaN                            0.000000
# 8                                   100                            1.821641
# 9                                   100                            0.695724
# 10                                  100                            4.617782
# 11                                  100                            0.728638
# 12                                  100                            1.574076
# 13                                  100                            0.034105
# 14                                  NaN                            0.000000
# 15                                  100                            1.248980
# 16                                  100                            1.364086
# 17                                  100                            0.002886
# 18                                  100                           28.284678
# 19                                  100                            1.295492
# 20                                  NaN                            0.000000
# 21                                  100                           18.956073
# 22                                  100                           15.364801
# 23                                  100                            4.696133
# 24                                  100                            0.418678
# 25                                  100                            0.035298
# 26                                  NaN                            0.000000
# 27                                  100                            0.185925
# 28                                  100                            0.371313
# 29                                  100                            0.055662
#
#     Average_coverage  total_reads_recruited mg_wgs_technology  mg_read_count  \
# 0           0.079989                   2601          illumina        5325310
# 1           0.000000                      0          illumina           2518
# 2           0.000000                      0          illumina          27452
# 3           0.043821                    457              pyro         772443
# 4           0.010251                     71              pyro        1323126
# 5           0.000000                      0              pyro        1182987
# 6           0.042969                     23          illumina        5325310
# 7           0.000000                      0          illumina           2518
# 8           0.037855                      5          illumina          27452
# 9           0.124096                     31              pyro         772443
# 10          0.282789                     76              pyro        1323126
# 11          0.057113                     17              pyro        1182987
# 12          4.988826                   8215          illumina        5325310
# 13          0.000336                      1          illumina           2518
# 14          0.000000                      0          illumina          27452
# 15          1.052517                   1451              pyro         772443
# 16          0.227484                   1528              pyro        1323126
# 17          0.000028                      1              pyro        1182987
# 18          5.814961                  48979          illumina        5325310
# 19          0.059863                     18          illumina           2518
# 20          0.000000                      0          illumina          27452
# 21          1.739441                   7740              pyro         772443
# 22          1.700178                   8711              pyro        1323126
# 23          0.182573                      4              pyro        1182987
# 24          0.014017                    147          illumina        5325310
# 25          0.000351                      1          illumina           2518
# 26          0.000000                      0          illumina          27452
# 27          0.005745                    342              pyro         772443
# 28          0.009437                    647              pyro        1323126
# 29          0.001138                     11              pyro        1182987
#
#     sag_completeness  sag_total_bp  sag_calculated_length  prop_mg_recruited  \
# 0              99.35       5256230                5290619       4.916178e-04
# 1              99.35       5256230                5290619       0.000000e+00
# 2              99.35       5256230                5290619       0.000000e+00
# 3              99.35       5256230                5290619       5.955002e-04
# 4              99.35       5256230                5290619       5.401188e-05
# 5              99.35       5256230                5290619       0.000000e+00
# 6              99.63       2929602                2940481       4.335037e-06
# 7              99.63       2929602                2940481       0.000000e+00
# 8              99.63       2929602                2940481       1.828125e-04
# 9              99.63       2929602                2940481       4.028145e-05
# 10             99.63       2929602                2940481       5.765305e-05
# 11             99.63       2929602                2940481       1.442377e-05
# 12            100.00       4394574                4394574       1.542633e-03
# 13            100.00       4394574                4394574       3.971406e-04
# 14            100.00       4394574                4394574       0.000000e+00
# 15            100.00       4394574                4394574       1.878456e-03
# 16            100.00       4394574                4394574       1.154841e-03
# 17            100.00       4394574                4394574       8.453178e-07
# 18             98.89       3092669                3127382       9.300636e-03
# 19             98.89       3092669                3127382       7.228770e-03
# 20             98.89       3092669                3127382       0.000000e+00
# 21             98.89       3092669                3127382       1.013263e-02
# 22             98.89       3092669                3127382       6.657550e-03
# 23             98.89       3092669                3127382       3.419225e-06
# 24             98.14       2886425                2941130       2.812719e-05
# 25             98.14       2886425                2941130       4.046674e-04
# 26             98.14       2886425                2941130       0.000000e+00
# 27             98.14       2886425                2941130       4.511424e-04
# 28             98.14       2886425                2941130       4.982611e-04
# 29             98.14       2886425                2941130       9.474726e-06
#
#     prop_mg_adjusted
# 0       4.117791e-04
# 1       0.000000e+00
# 2       0.000000e+00
# 3       5.955002e-04
# 4       5.401188e-05
# 5       0.000000e+00
# 6       3.631027e-06
# 7       0.000000e+00
# 8       1.531237e-04
# 9       4.028145e-05
# 10      5.765305e-05
# 11      1.442377e-05
# 12      1.292110e-03
# 13      3.326450e-04
# 14      0.000000e+00
# 15      1.878456e-03
# 16      1.154841e-03
# 17      8.453178e-07
# 18      7.790213e-03
# 19      6.054818e-03
# 20      0.000000e+00
# 21      1.013263e-02
# 22      6.657550e-03
# 23      3.419225e-06
# 24      2.355934e-05
# 25      3.389494e-04
# 26      0.000000e+00
# 27      4.511424e-04
# 28      4.982611e-04
# 29      9.474726e-06

# %%
mgs = ["SRS022524", "SRS019030","SRS078197","SRR063903","SRR063559","SRR061736"]
groups = ["A", "B", "C", "A", "B", "C"]
d = {"metagenome":mgs, "group":groups}
mg_grps = pd.DataFrame(d)

# %%
mg_grps
# Out:
#   group metagenome
# 0     A  SRS022524
# 1     B  SRS019030
# 2     C  SRS078197
# 3     A  SRR063903
# 4     B  SRR063559
# 5     C  SRR061736

# %%
summary = summary.merge(mg_grps, on="metagenome")

# %%
summary
# Out:
#     Unnamed: 0                 sag metagenome  \
# 0            0        Ecoli4147faa  SRS019030
# 1            0     EfaecalisTX1322  SRS019030
# 2            0     OlaneusYIT12061  SRS019030
# 3            0  PstercoreaDSM18206  SRS019030
# 4            0     Swadsworthensis  SRS019030
# 5            0        Ecoli4147faa  SRS022524
# 6            0     EfaecalisTX1322  SRS022524
# 7            0     OlaneusYIT12061  SRS022524
# 8            0  PstercoreaDSM18206  SRS022524
# 9            0     Swadsworthensis  SRS022524
# 10           0        Ecoli4147faa  SRS078197
# 11           0     EfaecalisTX1322  SRS078197
# 12           0     OlaneusYIT12061  SRS078197
# 13           0  PstercoreaDSM18206  SRS078197
# 14           0     Swadsworthensis  SRS078197
# 15           0        Ecoli4147faa  SRR063559
# 16           0     EfaecalisTX1322  SRR063559
# 17           0     OlaneusYIT12061  SRR063559
# 18           0  PstercoreaDSM18206  SRR063559
# 19           0     Swadsworthensis  SRR063559
# 20           0        Ecoli4147faa  SRR063903
# 21           0     EfaecalisTX1322  SRR063903
# 22           0     OlaneusYIT12061  SRR063903
# 23           0  PstercoreaDSM18206  SRR063903
# 24           0     Swadsworthensis  SRR063903
# 25           0        Ecoli4147faa  SRR061736
# 26           0     EfaecalisTX1322  SRR061736
# 27           0     OlaneusYIT12061  SRR061736
# 28           0  PstercoreaDSM18206  SRR061736
# 29           0     Swadsworthensis  SRR061736
#
#     Percent_scaffolds_with_any_coverage  Percent_of_reference_bases_covered  \
# 0                                   100                            7.366905
# 1                                   100                            2.404554
# 2                                   100                            1.574076
# 3                                   100                           28.284678
# 4                                   100                            0.418678
# 5                                   NaN                            0.000000
# 6                                   NaN                            0.000000
# 7                                   100                            0.034105
# 8                                   100                            1.295492
# 9                                   100                            0.035298
# 10                                  NaN                            0.000000
# 11                                  100                            1.821641
# 12                                  NaN                            0.000000
# 13                                  NaN                            0.000000
# 14                                  NaN                            0.000000
# 15                                  100                            3.687101
# 16                                  100                            0.695724
# 17                                  100                            1.248980
# 18                                  100                           18.956073
# 19                                  100                            0.185925
# 20                                  100                            0.631277
# 21                                  100                            4.617782
# 22                                  100                            1.364086
# 23                                  100                           15.364801
# 24                                  100                            0.371313
# 25                                  NaN                            0.000000
# 26                                  100                            0.728638
# 27                                  100                            0.002886
# 28                                  100                            4.696133
# 29                                  100                            0.055662
#
#     Average_coverage  total_reads_recruited mg_wgs_technology  mg_read_count  \
# 0           0.079989                   2601          illumina        5325310
# 1           0.042969                     23          illumina        5325310
# 2           4.988826                   8215          illumina        5325310
# 3           5.814961                  48979          illumina        5325310
# 4           0.014017                    147          illumina        5325310
# 5           0.000000                      0          illumina           2518
# 6           0.000000                      0          illumina           2518
# 7           0.000336                      1          illumina           2518
# 8           0.059863                     18          illumina           2518
# 9           0.000351                      1          illumina           2518
# 10          0.000000                      0          illumina          27452
# 11          0.037855                      5          illumina          27452
# 12          0.000000                      0          illumina          27452
# 13          0.000000                      0          illumina          27452
# 14          0.000000                      0          illumina          27452
# 15          0.043821                    457              pyro         772443
# 16          0.124096                     31              pyro         772443
# 17          1.052517                   1451              pyro         772443
# 18          1.739441                   7740              pyro         772443
# 19          0.005745                    342              pyro         772443
# 20          0.010251                     71              pyro        1323126
# 21          0.282789                     76              pyro        1323126
# 22          0.227484                   1528              pyro        1323126
# 23          1.700178                   8711              pyro        1323126
# 24          0.009437                    647              pyro        1323126
# 25          0.000000                      0              pyro        1182987
# 26          0.057113                     17              pyro        1182987
# 27          0.000028                      1              pyro        1182987
# 28          0.182573                      4              pyro        1182987
# 29          0.001138                     11              pyro        1182987
#
#     sag_completeness  sag_total_bp  sag_calculated_length  prop_mg_recruited  \
# 0              99.35       5256230                5290619       4.916178e-04
# 1              99.63       2929602                2940481       4.335037e-06
# 2             100.00       4394574                4394574       1.542633e-03
# 3              98.89       3092669                3127382       9.300636e-03
# 4              98.14       2886425                2941130       2.812719e-05
# 5              99.35       5256230                5290619       0.000000e+00
# 6              99.63       2929602                2940481       0.000000e+00
# 7             100.00       4394574                4394574       3.971406e-04
# 8              98.89       3092669                3127382       7.228770e-03
# 9              98.14       2886425                2941130       4.046674e-04
# 10             99.35       5256230                5290619       0.000000e+00
# 11             99.63       2929602                2940481       1.828125e-04
# 12            100.00       4394574                4394574       0.000000e+00
# 13             98.89       3092669                3127382       0.000000e+00
# 14             98.14       2886425                2941130       0.000000e+00
# 15             99.35       5256230                5290619       5.955002e-04
# 16             99.63       2929602                2940481       4.028145e-05
# 17            100.00       4394574                4394574       1.878456e-03
# 18             98.89       3092669                3127382       1.013263e-02
# 19             98.14       2886425                2941130       4.511424e-04
# 20             99.35       5256230                5290619       5.401188e-05
# 21             99.63       2929602                2940481       5.765305e-05
# 22            100.00       4394574                4394574       1.154841e-03
# 23             98.89       3092669                3127382       6.657550e-03
# 24             98.14       2886425                2941130       4.982611e-04
# 25             99.35       5256230                5290619       0.000000e+00
# 26             99.63       2929602                2940481       1.442377e-05
# 27            100.00       4394574                4394574       8.453178e-07
# 28             98.89       3092669                3127382       3.419225e-06
# 29             98.14       2886425                2941130       9.474726e-06
#
#     prop_mg_adjusted group
# 0       4.117791e-04     B
# 1       3.631027e-06     B
# 2       1.292110e-03     B
# 3       7.790213e-03     B
# 4       2.355934e-05     B
# 5       0.000000e+00     A
# 6       0.000000e+00     A
# 7       3.326450e-04     A
# 8       6.054818e-03     A
# 9       3.389494e-04     A
# 10      0.000000e+00     C
# 11      1.531237e-04     C
# 12      0.000000e+00     C
# 13      0.000000e+00     C
# 14      0.000000e+00     C
# 15      5.955002e-04     B
# 16      4.028145e-05     B
# 17      1.878456e-03     B
# 18      1.013263e-02     B
# 19      4.511424e-04     B
# 20      5.401188e-05     A
# 21      5.765305e-05     A
# 22      1.154841e-03     A
# 23      6.657550e-03     A
# 24      4.982611e-04     A
# 25      0.000000e+00     C
# 26      1.442377e-05     C
# 27      8.453178e-07     C
# 28      3.419225e-06     C
# 29      9.474726e-06     C

# %%
# %load_ext rpy2.ipython
# %R library(ggplot2); library(dplyr)
# Out:
# //anaconda/lib/python2.7/site-packages/rpy2/robjects/functions.py:106: UserWarning:
# Attaching package: ‘dplyr’
#
#
#   res = super(Function, self).__call__(*new_args, **new_kwargs)
# //anaconda/lib/python2.7/site-packages/rpy2/robjects/functions.py:106: UserWarning: The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
#
#   res = super(Function, self).__call__(*new_args, **new_kwargs)
# //anaconda/lib/python2.7/site-packages/rpy2/robjects/functions.py:106: UserWarning: The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union
#
#
#   res = super(Function, self).__call__(*new_args, **new_kwargs)
# array(['dplyr', 'ggplot2', 'tools', 'stats', 'graphics', 'grDevices',
#        'utils', 'datasets', 'methods', 'base'],
#       dtype='|S9')

# %%
# %%R -i summary
# head(summary)
# Out:
#   Unnamed..0                sag metagenome Percent_scaffolds_with_any_coverage
# 0          0       Ecoli4147faa  SRS019030                                 100
# 1          0    EfaecalisTX1322  SRS019030                                 100
# 2          0    OlaneusYIT12061  SRS019030                                 100
# 3          0 PstercoreaDSM18206  SRS019030                                 100
# 4          0    Swadsworthensis  SRS019030                                 100
# 5          0       Ecoli4147faa  SRS022524                                 NaN
#   Percent_of_reference_bases_covered Average_coverage total_reads_recruited
# 0                          7.3669053       0.07998874                  2601
# 1                          2.4045540       0.04296876                    23
# 2                          1.5740761       4.98882629                  8215
# 3                         28.2846776       5.81496074                 48979
# 4                          0.4186781       0.01401729                   147
# 5                          0.0000000       0.00000000                     0
#   mg_wgs_technology mg_read_count sag_completeness sag_total_bp
# 0          illumina       5325310            99.35      5256230
# 1          illumina       5325310            99.63      2929602
# 2          illumina       5325310           100.00      4394574
# 3          illumina       5325310            98.89      3092669
# 4          illumina       5325310            98.14      2886425
# 5          illumina          2518            99.35      5256230
#   sag_calculated_length prop_mg_recruited prop_mg_adjusted group
# 0               5290619      4.916178e-04     4.117791e-04     B
# 1               2940481      4.335037e-06     3.631027e-06     B
# 2               4394574      1.542633e-03     1.292110e-03     B
# 3               3127382      9.300636e-03     7.790213e-03     B
# 4               2941130      2.812719e-05     2.355934e-05     B
# 5               5290619      0.000000e+00     0.000000e+00     A

# %%
# %%R
# summary %>% filter(mg_wgs_technology=="illumina") -> ill
# summary %>% filter(mg_wgs_technology=="pyro") -> py
#
# colnames(ill) <- paste(colnames(ill), "_i", sep="")
# colnames(py) <- paste(colnames(py), "_p", sep="")
# colnames(ill)[2] <- "sag"
# colnames(py)[2] <- "sag"
# colnames(ill)[15] <- "group"
# colnames(py)[15] <- "group"
#
# sbs <- merge(ill, py, by=c("sag","group"))
# sbs
# Out:
#                   sag group Unnamed..0_i metagenome_i
# 1        Ecoli4147faa     A            0    SRS022524
# 2        Ecoli4147faa     B            0    SRS019030
# 3        Ecoli4147faa     C            0    SRS078197
# 4     EfaecalisTX1322     A            0    SRS022524
# 5     EfaecalisTX1322     B            0    SRS019030
# 6     EfaecalisTX1322     C            0    SRS078197
# 7     OlaneusYIT12061     A            0    SRS022524
# 8     OlaneusYIT12061     B            0    SRS019030
# 9     OlaneusYIT12061     C            0    SRS078197
# 10 PstercoreaDSM18206     A            0    SRS022524
# 11 PstercoreaDSM18206     B            0    SRS019030
# 12 PstercoreaDSM18206     C            0    SRS078197
# 13    Swadsworthensis     A            0    SRS022524
# 14    Swadsworthensis     B            0    SRS019030
# 15    Swadsworthensis     C            0    SRS078197
#    Percent_scaffolds_with_any_coverage_i Percent_of_reference_bases_covered_i
# 1                                    NaN                           0.00000000
# 2                                    100                           7.36690526
# 3                                    NaN                           0.00000000
# 4                                    NaN                           0.00000000
# 5                                    100                           2.40455404
# 6                                    100                           1.82164063
# 7                                    100                           0.03410462
# 8                                    100                           1.57407609
# 9                                    NaN                           0.00000000
# 10                                   100                           1.29549210
# 11                                   100                          28.28467758
# 12                                   NaN                           0.00000000
# 13                                   100                           0.03529795
# 14                                   100                           0.41867813
# 15                                   NaN                           0.00000000
#    Average_coverage_i total_reads_recruited_i mg_wgs_technology_i
# 1        0.0000000000                       0            illumina
# 2        0.0799887376                    2601            illumina
# 3        0.0000000000                       0            illumina
# 4        0.0000000000                       0            illumina
# 5        0.0429687573                      23            illumina
# 6        0.0378553144                       5            illumina
# 7        0.0003358011                       1            illumina
# 8        4.9888262890                    8215            illumina
# 9        0.0000000000                       0            illumina
# 10       0.0598628658                      18            illumina
# 11       5.8149607431                   48979            illumina
# 12       0.0000000000                       0            illumina
# 13       0.0003507176                       1            illumina
# 14       0.0140172876                     147            illumina
# 15       0.0000000000                       0            illumina
#    mg_read_count_i sag_completeness_i sag_total_bp_i sag_calculated_length_i
# 1             2518              99.35        5256230                 5290619
# 2          5325310              99.35        5256230                 5290619
# 3            27452              99.35        5256230                 5290619
# 4             2518              99.63        2929602                 2940481
# 5          5325310              99.63        2929602                 2940481
# 6            27452              99.63        2929602                 2940481
# 7             2518             100.00        4394574                 4394574
# 8          5325310             100.00        4394574                 4394574
# 9            27452             100.00        4394574                 4394574
# 10            2518              98.89        3092669                 3127382
# 11         5325310              98.89        3092669                 3127382
# 12           27452              98.89        3092669                 3127382
# 13            2518              98.14        2886425                 2941130
# 14         5325310              98.14        2886425                 2941130
# 15           27452              98.14        2886425                 2941130
#    prop_mg_recruited_i prop_mg_adjusted_i Unnamed..0_p metagenome_p
# 1         0.000000e+00       0.000000e+00            0    SRR063903
# 2         4.916178e-04       4.117791e-04            0    SRR063559
# 3         0.000000e+00       0.000000e+00            0    SRR061736
# 4         0.000000e+00       0.000000e+00            0    SRR063903
# 5         4.335037e-06       3.631027e-06            0    SRR063559
# 6         1.828125e-04       1.531237e-04            0    SRR061736
# 7         3.971406e-04       3.326450e-04            0    SRR063903
# 8         1.542633e-03       1.292110e-03            0    SRR063559
# 9         0.000000e+00       0.000000e+00            0    SRR061736
# 10        7.228770e-03       6.054818e-03            0    SRR063903
# 11        9.300636e-03       7.790213e-03            0    SRR063559
# 12        0.000000e+00       0.000000e+00            0    SRR061736
# 13        4.046674e-04       3.389494e-04            0    SRR063903
# 14        2.812719e-05       2.355934e-05            0    SRR063559
# 15        0.000000e+00       0.000000e+00            0    SRR061736
#    Percent_scaffolds_with_any_coverage_p Percent_of_reference_bases_covered_p
# 1                                    100                          0.631276947
# 2                                    100                          3.687100801
# 3                                    NaN                          0.000000000
# 4                                    100                          4.617781547
# 5                                    100                          0.695723981
# 6                                    100                          0.728638020
# 7                                    100                          1.364085758
# 8                                    100                          1.248979514
# 9                                    100                          0.002885595
# 10                                   100                         15.364800657
# 11                                   100                         18.956072799
# 12                                   100                          4.696132597
# 13                                   100                          0.371312882
# 14                                   100                          0.185925186
# 15                                   100                          0.055662153
#    Average_coverage_p total_reads_recruited_p mg_wgs_technology_p
# 1        1.025134e-02                      71                pyro
# 2        4.382114e-02                     457                pyro
# 3        0.000000e+00                       0                pyro
# 4        2.827890e-01                      76                pyro
# 5        1.240957e-01                      31                pyro
# 6        5.711345e-02                      17                pyro
# 7        2.274843e-01                    1528                pyro
# 8        1.052517e+00                    1451                pyro
# 9        2.807609e-05                       1                pyro
# 10       1.700178e+00                    8711                pyro
# 11       1.739441e+00                    7740                pyro
# 12       1.825726e-01                       4                pyro
# 13       9.436636e-03                     647                pyro
# 14       5.745192e-03                     342                pyro
# 15       1.138135e-03                      11                pyro
#    mg_read_count_p sag_completeness_p sag_total_bp_p sag_calculated_length_p
# 1          1323126              99.35        5256230                 5290619
# 2           772443              99.35        5256230                 5290619
# 3          1182987              99.35        5256230                 5290619
# 4          1323126              99.63        2929602                 2940481
# 5           772443              99.63        2929602                 2940481
# 6          1182987              99.63        2929602                 2940481
# 7          1323126             100.00        4394574                 4394574
# 8           772443             100.00        4394574                 4394574
# 9          1182987             100.00        4394574                 4394574
# 10         1323126              98.89        3092669                 3127382
# 11          772443              98.89        3092669                 3127382
# 12         1182987              98.89        3092669                 3127382
# 13         1323126              98.14        2886425                 2941130
# 14          772443              98.14        2886425                 2941130
# 15         1182987              98.14        2886425                 2941130
#    prop_mg_recruited_p prop_mg_adjusted_p
# 1         5.401188e-05       5.401188e-05
# 2         5.955002e-04       5.955002e-04
# 3         0.000000e+00       0.000000e+00
# 4         5.765305e-05       5.765305e-05
# 5         4.028145e-05       4.028145e-05
# 6         1.442377e-05       1.442377e-05
# 7         1.154841e-03       1.154841e-03
# 8         1.878456e-03       1.878456e-03
# 9         8.453178e-07       8.453178e-07
# 10        6.657550e-03       6.657550e-03
# 11        1.013263e-02       1.013263e-02
# 12        3.419225e-06       3.419225e-06
# 13        4.982611e-04       4.982611e-04
# 14        4.511424e-04       4.511424e-04
# 15        9.474726e-06       9.474726e-06

# %%
# %%R -w 600
# sbs %>% ggplot(aes(prop_mg_recruited_i, prop_mg_recruited_p, color=sag)) + geom_point()

# %%
# %%R
# # from: https://susanejohnston.wordpress.com/2012/08/09/a-quick-and-easy-function-to-plot-lm-results-in-r/
# ggplotRegression <- function (fit) {
#
# require(ggplot2)
#
# ggplot(fit$model, aes_string(x = names(fit$model)[2], y = names(fit$model)[1])) +
#   geom_point(size=3) +
#   stat_smooth(method = "lm", col = "grey") +
#   labs(title = paste("Adj R2 = ",signif(summary(fit)$adj.r.squared, 5),
#                      "Intercept =",signif(fit$coef[[1]],5 ),"\n",
#                      " Slope =",signif(fit$coef[[2]], 5),
#                      " P =",signif(summary(fit)$coef[2,4], 5)))
# }

# %%
# %%R
# fit1 <- lm(prop_mg_recruited_i ~ prop_mg_recruited_p, data = sbs)
# ggplotRegression(fit1)+theme_bw()+labs(x="Illumina Reads Recruited", y="454 Reads Recruited")

# %%
# %%R
# fit1 <- lm(prop_mg_adjusted_i ~ prop_mg_adjusted_p, data = sbs)
# ggplotRegression(fit1)+theme_bw()+labs(x="Illumina Reads Recruited", y="454 Reads Recruited")
